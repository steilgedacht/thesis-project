# %%
import pandas as pd

# %% [markdown]
# How many patients?

# %%
d = pd.read_excel("../../data/Yale-Brain-Mets-Longitudinal_ClinicalData_20250605.xlsx", sheet_name="Clinical_data")
d["patient_id"].value_counts()
# Out:
# patient_id
# YG_C9D2TEGNY08A    66
# YG_NRSFSRTTONBY    49
# YG_2LEC0G5PJYWI    48
# YG_Y57DU8SLLWAH    47
# YG_MTO9K0JU7M07    42
#                    ..
# YG_Z7O6FBQQ6T8Z     1
# YG_ZHW4SBC4MJ3U     1
# YG_ZIPW4WAWTWM0     1
# YG_ZK49IL615MDA     1
# YG_ZLSCOVI5URAO     1
# Name: count, Length: 1430, dtype: int64

# %%
sorted(d["age_at_Imaging (years)"].unique())
# Out:
# [np.int64(-17),
#  np.int64(9),
#  np.int64(10),
#  np.int64(11),
#  np.int64(12),
#  np.int64(13),
#  np.int64(14),
#  np.int64(15),
#  np.int64(16),
#  np.int64(21),
#  np.int64(22),
#  np.int64(23),
#  np.int64(24),
#  np.int64(25),
#  np.int64(26),
#  np.int64(27),
#  np.int64(28),
#  np.int64(29),
#  np.int64(30),
#  np.int64(31),
#  np.int64(32),
#  np.int64(33),
#  np.int64(34),
#  np.int64(35),
#  np.int64(36),
#  np.int64(37),
#  np.int64(38),
#  np.int64(39),
#  np.int64(40),
#  np.int64(41),
#  np.int64(42),
#  np.int64(43),
#  np.int64(44),
#  np.int64(45),
#  np.int64(46),
#  np.int64(47),
#  np.int64(48),
#  np.int64(49),
#  np.int64(50),
#  np.int64(51),
#  np.int64(52),
#  np.int64(53),
#  np.int64(54),
#  np.int64(55),
#  np.int64(56),
#  np.int64(57),
#  np.int64(58),
#  np.int64(59),
#  np.int64(60),
#  np.int64(61),
#  np.int64(62),
#  np.int64(63),
#  np.int64(64),
#  np.int64(65),
#  np.int64(66),
#  np.int64(67),
#  np.int64(68),
#  np.int64(69),
# ...

# %%
sorted(d["study_datetime"].str.split("-").str[0].unique())
# Out:
# ['2004',
#  '2005',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2021',
#  '2022',
#  '2023']

# %%
d = pd.read_excel("../../data/Yale-Brain-Mets-Longitudinal_ClinicalData_20250605.xlsx", sheet_name="image_acquisition_parameters")
d["sequence_class"].value_counts()
# Out:
# sequence_class
# FLAIR    9084
# POST     8996
# PRE      8384
# T2       7348
# Name: count, dtype: int64

# %%
sorted(d["slice_thickness (mm)"].unique())
# Out:
# [np.float64(0.59999996423721),
#  np.float64(0.89999997615814),
#  np.float64(0.9),
#  np.float64(0.90000003576279),
#  np.float64(0.93999999761581),
#  np.float64(1.0),
#  np.float64(1.0499999523163),
#  np.float64(1.1000000238419),
#  np.float64(1.4),
#  np.float64(1.5),
#  np.float64(2.0),
#  np.float64(3.0),
#  np.float64(3.5),
#  np.float64(4.0),
#  np.float64(4.4000000953674),
#  np.float64(4.5),
#  np.float64(5.0),
#  np.float64(5.0999999046326),
#  np.float64(5.4),
#  np.float64(5.5),
#  np.float64(6.0)]
